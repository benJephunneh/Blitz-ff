# %%
import csv
import pandas as pd
import json
import re
from customer import Customer as C
from location import Location as L
from customerList import CustomerList as CL
import helperFuncs as hf

# %%
# Test data:
rows = [
  {
    'ID': 124,
    'First name' : 'Bob',
    'Last name' : 'Han',
    'Company name': '',
    'Nickname': 'Bobby',
    'Primary?': 'no',
    'Parent ID': 235234,
    'Mobile phone': '8508777777',
    'Home phone': '',
    'Office phone': '',
    'Email': 'lzhang22@gmail.com',
    'Preferred notification method': 'do not notify',
    'Street one': '99 Frances Harrell Way',
    'Street two': '',
    'City': 'Tallahassee',
    'State': 'FL',
    'Postal code': '32343',
    'Tags': '',
  },
  {
    'ID': 200,
    'First name' : 'Bob',
    'Last name' : 'Han',
    'Company name': '',
    'Nickname': 'Bobby',
    'Primary?': 'no',
    'Parent ID': 235234,
    'Mobile phone': '8508777777',
    'Home phone': '',
    'Office phone': '',
    'Email': 'lzhang22@gmail.com',
    'Preferred notification method': 'do not notify',
    'Street one': 'Bob Han',
    'Street two': '1519 Killearn Center Blvd',
    'City': 'Tallahassee',
    'State': 'FL',
    'Postal code': '32343',
    'Tags': '',
  },
  {
    'ID': 125,
    'First name' : '',
    'Last name' : '',
    'Company name': '',
    'Nickname': 'Bobby',
    'Primary?': 'no',
    'Parent ID': 235234,
    'Mobile phone': '',
    'Home phone': '02390f0a9f',
    'Office phone': '',
    'Email': 'lzhang22@gmail.com',
    'Preferred notification method': 'do not notify',
    'Street one': '315 Mae Cato Rd',
    'Street two': '',
    'City': 'Midway',
    'State': 'FL',
    'Postal code': '32343',
    'Tags': '',
  },
  {
    'ID': 122356,
    'First name' : 'Cheryl',
    'Last name' : 'Oldani',
    'Company name': '',
    'Nickname': '',
    'Primary?': 'no',
    'Parent ID': 23529,
    'Mobile phone': '',
    'Home phone': '902309f2f',
    'Office phone': '',
    'Email': 'cheryl.oldani@gmail.com',
    'Preferred notification method': 'do not notify',
    'Street one': '75 Old Lloyd Rd',
    'Street two': '',
    'City': 'Monticello',
    'State': 'FL',
    'Postal code': '32342',
    'Tags': '',
  },
  {
    'firstname': 'Joe',
    'lastname': 'Adams',
    'companyname': '',
    'email': 'joeadamscoast@comcast.net',
    'phones': [
      '3217398',
    ],
    'locations': [
      {
        'address1': '3544 Oakhill Trail',
        'address2': '',
        'city': 'Tallahassee',
        'state': 'FL',
        'zipcode': '32312',
        'primary': True,
      },
      {
        'address1': 'Old Dirt Rd',
        'address2': '',
        'city': 'Tallahassee',
        'state': 'FL',
        'zipcode': '32317',
        'primary': False,
      },
    ],
  },
  {
    'ID': 100,
    'First name': 'Bob',
    'Last name': 'Han',
    'Company name': '',
    'Nickname': '',
    'Primary?': 'no',
    'Parent ID': 101,
    'Mobile phone': '',
    'Home phone': '',
    'Office phone': '',
    'Email': 'lzhang22@gmail.com',
    'Preferred notification method': 'do not notify',
    'Street one': '415 Mae Cato Rd',
    'Street two': '',
    'City': 'Midway',
    'State': 'FL',
    'Postal code': '32343',
    'Tags': '',
  },
  {
    'ID': 102,
    'First name': 'Joe',
    'Last name': 'Adams',
    'Company name': 'Adams Quality Homes',
    'Nickname': '',
    'Primary?': 'no',
    'Parent ID': 101,
    'Mobile phone': '3197878',
    'Home phone': '3217398',
    'Office phone': '5709242',
    'Email': 'joeadamscoast@comcast.net',
    'Preferred notification method': 'do not notify',
    'Street one': '3733 Tom John Ln',
    'Street two': '',
    'City': 'Tallahassee',
    'State': 'FL',
    'Postal code': '32309',
    'Tags': '',
  },
  {
    'ID': 101,
    'First name': 'Joe',
    'Last name': 'Adams',
    'Company name': 'Adams Quality Homes',
    'Nickname': '',
    'Primary?': 'yes',
    'Parent ID': 101,
    'Mobile phone': '3197878',
    'Home phone': '3217398',
    'Office phone': '5709242',
    'Email': 'joeadamscoast@comcast.net',
    'Preferred notification method': 'do not notify',
    'Street one': '3544 Oakhill Trail',
    'Street two': '',
    'City': 'Tallahassee',
    'State': 'FL',
    'Postal code': '32312',
    'Tags': '',
  },
  {
    'ID': 101,
    'First name': 'Joe',
    'Last name': 'Adams',
    'Company name': 'Adams Quality Homes',
    'Nickname': '',
    'Primary?': 'yes',
    'Parent ID': 101,
    'Mobile phone': '3197878',
    'Home phone': '',
    'Office phone': '5709242',
    'Email': 'joeadamscoast@comcast.net',
    'Preferred notification method': 'do not notify',
    'Street one': '3544 Oakhill Trail',
    'Street two': '',
    'City': 'Tallahassee',
    'State': 'FL',
    'Postal code': '32312',
    'Tags': '',
  },
  {
    'ID': 103,
    'First name': 'Joe',
    'Last name': 'Adams',
    'Company name': 'Adams Quality Homes',
    'Nickname': '',
    'Primary?': 'no',
    'Parent ID': 101,
    'Mobile phone': '3197878',
    'Home phone': '3217398',
    'Office phone': '5709242',
    'Email': 'joeadamscoast@comcast.net',
    'Preferred notification method': 'do not notify',
    'Street one': '2070 Solomon Ct',
    'Street two': '',
    'City': 'Tallahassee',
    'State': 'FL',
    'Postal code': '32312',
    'Tags': '',
  },
]

# %%
c0 = C(rows[0])
c1 = C(rows[1])
c2 = C(rows[2])
c3 = C(rows[3])
print(c0, c1, c2, c3)
# print(c0 == c1)
# print(c0 == c3)

# cl = CL()
# cl.append(c0)
# cl.append(c1)
# cl.append(c3)

# print(cl)
# print(cl[0])

# print(cl)
# Out:
# {'firstname': 'Bob', 'lastname': 'Han', 'companyname': '', 'phone': '8508777777', 'email': 'lzhang22@gmail.com'} {'firstname': 'Bob', 'lastname': 'Han', 'companyname': '', 'phone': '8508777777', 'email': 'lzhang22@gmail.com'} {} {}

# %%
csvFile = r'customers.csv'
newCsvFile= r'customers_edited.csv'
jsonFile = r'customerMakeCustomer.json'
customerfile = r'customerfile.csv'
locationfile = r'locationfile.csv'
dataDict = []

readFieldnames = [
  'ID',
  'First name',
  'Last name',
  'Company name',
  'Nickname',
  'Primary?',
  'Parent ID',
  'Mobile phone',
  'Home phone',
  'Office phone',
  'Email',
  'Preferred notification method',
  'Street one',
  'Street two',
  'City',
  'State',
  'Postal code',
  'Tags',
]

# writeFieldnames = [
#   'First name',
#   'Last name',
#   'Company name',
#   'Nickname',
#   'Primary?',
#   'Mobile phone',
#   'Home phone',
#   'Office phone',
#   'Email',
#   'Street one',
#   'Street two',
#   'City',
#   'State',
#   'Postal code',
#   'Tags',
# ]

customerFieldnames = [
  'firstname',
  'lastname',
  # 'displayname',
  'companyname',
  'email',
  'phone',
  # 'locations',
  # 'locationStashes',
  # 'jobs',
  # 'jobStashes',
  # 'user',
  # 'userId',
]

locationFieldnames = [
  'primary',
  'house',
  'street',
  'city',
  'state',
  'zipcode',
  'block',
  'lot',
  'parcel',
  'locationType',
  # 'customer',
  # 'customerId',
  # 'jobs',
  # 'jobStashes',
  # 'user',
  # 'userId',
  'notes',
]

# %%
# csvData = pd.read_csv(csvFile)
# sortedCsvData = csvData.sort_values(['Email'], na_position='first')
# uniqueEmails = sortedCsvData[sortedCsvData.Email.notnull()].Email.unique()
# # print(uniqueEmails)
# hanData = sortedCsvData.loc[sortedCsvData.Email == 'lzhang22@aol.com']
# print(hanData)


# for email in uniqueEmails:
#   if not pd.isna(email):
#     temp = sortedCsvData[sortedCsvData['Email'] == email]
#     Start with primary location
#     # exclude rows with no fn, ln, cn, and nn
#     if (len())
#     loc = 
#         find all entries related to that email (i.e. find all locations for that customer)
#         store locations

# %%
cl = CL()
ll = LL()

with open(csvFile, 'r') as data, \
  open(customerfile, 'w', newline='') as customerWriter, \
  open(locationFile, 'w', newline='') as locationWriter:

  csvDR = csv.DictReader(data)
  # Customer writer:
  cw = csv.DictWriter(customerWriter, fieldnames=customerFieldnames, quoting=csv.QUOTE_ALL)
  cw.writeheader()
  # Location writer:
  lw = csv.DictWriter(locationWriter, fieldnames=locationFieldnames, quoting=csv.QUOTE_ALL)
  lw.writeheader()

  for row in csvDR:
    try:
      c = C(row)
      l = L(row)
      # print(c)
      # print(l)
      if cl.append(c) and ll.append(l):
        cw.writerow(c)
        lw.writerow(l)
    except:
      continue
    
    
# print(len(cl))
# Out:
# {'firstname': 'Leon County Housing', 'lastname': '(LCHHS)', 'companyname': 'Leon Co. Housing & Human Services', 'phone': '6061919', 'email': 'twymanl@leoncountyfl.gov'}
# {'firstname': '[REDACTED]', 'lastname': '[REDACTED]', 'companyname': '', 'phone': '5240027', 'email': 'djsharp1212@gmail.com'}
# {'firstname': 'Cindy', 'lastname': 'Abaco', 'companyname': '', 'phone': '9339132', 'email': 'ocabaco@embarqmail.com'}
# {'firstname': 'Buddy', 'lastname': 'Abbott', 'companyname': '', 'phone': '2516549', 'email': 'annabbott6026@centurylink.net'}
# {'firstname': '', 'lastname': 'adams', 'companyname': '', 'phone': '3090800', 'email': 'jbodkin@americashomeplace.com'}
# {'firstname': '', 'lastname': 'Adams', 'companyname': '', 'phone': '5454401', 'email': 'kenleydesign@gmail.com'}
# {'firstname': 'Dale', 'lastname': 'Adams', 'companyname': 'Keller Williams Realty', 'phone': '5087114', 'email': 'daleadams@kw.com'}
# {'firstname': 'Heather', 'lastname': 'Adams', 'companyname': '', 'phone': '2739340', 'email': 'hlcadams@aol.com'}
# {'firstname': 'Jessica', 'lastname': 'Adams', 'companyname': '', 'phone': '7661418', 'email': 'jessica.nichole87@yahoo.com'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': 'Adams Quality Homes', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Joseph', 'lastname': 'Adams', 'companyname': '', 'phone': '5709242', 'email': 'joeadamscoast@comcast.net'}
# {'firstname': 'Robert', 'lastname': 'Adams', 'companyname': 'RK Adams Construction', 'phone': '5244891', 'email': 'rkadamshomes@yahoo.com'}
# {'firstname': 'Robert', 'lastname': 'Adams', 'companyname': 'RK Adams Construction', 'phone': '5244891', 'email': 'rkadamshomes@yahoo.com'}
# {'firstname': 'Kimberly', 'lastname': 'Adcock', 'companyname': '', 'phone': '5564130', 'email': 'cadcock@fsucu.org'}
# {'firstname': 'Kimberly', 'lastname': 'Adcock', 'companyname': '', 'phone': '5564130', 'email': 'kadcock1011@gmail.com'}
# {'firstname': 'Frank', 'lastname': 'Adkinson', 'companyname': '', 'phone': '3810346', 'email': 'fdadkinson@yahoo.com'}
# {'firstname': 'Chris', 'lastname': 'Adkison', 'companyname': '', 'phone': '5241851', 'email': 'chris.adkison11@yahoo.com'}
# {'firstname': 'Katherine', 'lastname': 'Ajmeri', 'companyname': '', 'phone': '6884305', 'email': 'klee_phife@yahoo.com'}
# {'firstname': 'Fred', 'lastname': 'Akers', 'companyname': '', 'phone': '5663896', 'email': 'auraus1@yahoo.com'}
# {'firstname': 'Tom', 'lastname': 'Albert', 'companyname': '', 'phone': '8940051', 'email': 'tomalbert314@gmail.com'}
# {'firstname': 'Lee', 'lastname': 'Alday', 'companyname': 'A1 Services', 'phone': '2726995', 'email': 'armcocabinets@hotmail.com'}
# {'firstname': 'Theresa', 'lastname': 'Aldridge', 'companyname': '', 'phone': '2840572', 'email': 'taaldridge@gmail.com'}
# {'firstname': 'Rachel', 'lastname': 'Alexander', 'companyname': '', 'phone': '2062199', 'email': 'rachelflrealtor@gmail.com'}
# {'firstname': 'Libby', 'lastname': 'Allen, Realtor', 'companyname': '', 'phone': '6687653', 'email': 'libbyallen@aol.com'}
# {'firstname': 'Glen', 'lastname': 'Allen', 'companyname': '', 'phone': '5806845', 'email': 'kjeffries732@embarqmail.com'}
# {'firstname': 'Libby', 'lastname': 'Allen', 'companyname': '', 'phone': '6687653', 'email': 'libbyallen@aol.com'}
# {'firstname': 'Mike', 'lastname': 'Allen', 'companyname': '', 'phone': '7027827', 'email': 'mallen.ccreg@gmail.com'}
# {'firstname': 'Rob', 'lastname': 'Allen', 'companyname': '', 'phone': '9806002', 'email': 'beth@robertjallen.com'}
# {'firstname': 'Timothy', 'lastname': 'Allen', 'companyname': '', 'phone': '5102199', 'email': 'captaintim.ta@gmail.com'}
# {'firstname': 'Timothy', 'lastname': 'Allen', 'companyname': '', 'phone': '5102199', 'email': 'captaintim.ta@gmail.com'}
# {'firstname': 'Gary', 'lastname': 'Allshouse', 'companyname': '', 'phone': '9267505', 'email': 'gallhouse@hotmail.com'}
# {'firstname': 'Justin', 'lastname': 'Altavilla', 'companyname': '', 'phone': '5706065', 'email': 'justinaltavilla@yahoo.com'}
# {'firstname': 'Jen', 'lastname': 'Altrogge', 'companyname': '', 'phone': '5194371', 'email': 'stephenaltrogge@gmail.com'}
# {'firstname': 'Mark and Marilyn', 'lastname': 'Alvarez', 'companyname': '', 'phone': '4024133', 'email': 'markalvarez@embarqmail.com'}
# {'firstname': 'Frank', 'lastname': 'Amidon', 'companyname': '', 'phone': '3392152', 'email': 'amidon088@comcast.net'}
# {'firstname': 'Jessi', 'lastname': 'Ammons', 'companyname': '', 'phone': '3090800', 'email': 'jbodkin@americashomeplace.com'}
# {'firstname': 'David', 'lastname': 'Anderson', 'companyname': '', 'phone': '5701341', 'email': 'danderson1sg@gmail.com'}
# {'firstname': 'Diane', 'lastname': 'Anderson', 'companyname': '', 'phone': '9332398', 'email': 'wooddival@comcast.net'}
# {'firstname': 'John', 'lastname': 'Anderson', 'companyname': '', 'phone': '5454859', 'email': 'larryanderson2828@yahoo.com'}
# {'firstname': 'Peggy', 'lastname': 'Anderson', 'companyname': '', 'phone': '5678121', 'email': 'pgganderson5@gmail.com'}
# {'firstname': 'Rick', 'lastname': 'Anderson', 'companyname': '', 'phone': '4452964', 'email': 'r.anderson@pearlstreetholdings.com'}
# {'firstname': 'Virginia', 'lastname': 'Anderson', 'companyname': '', 'phone': '3854748', 'email': 'ginande@comcast.net'}
# {'firstname': 'Emilia', 'lastname': 'Andrei', 'companyname': '', 'phone': '6880325', 'email': 'emiliasndrei@comcast.net'}
# {'firstname': 'Ben', 'lastname': 'Andrews', 'companyname': '', 'phone': '4458181', 'email': 'benandrewsllc@gmail.com'}
# {'firstname': 'Franklin', 'lastname': 'Andrews', 'companyname': '', 'phone': '8774817', 'email': 'cass97ole@gmail.com'}
# {'firstname': 'Kendall', 'lastname': 'Andrews', 'companyname': '', 'phone': '3634483', 'email': 'trucker7933@yahoo.com'}
# {'firstname': 'Matthew and Kathleen', 'lastname': 'Andrews', 'companyname': '', 'phone': '6681008', 'email': 'mattkathyandrews@gmail.com'}
# {'firstname': 'Jerry', 'lastname': 'Angulo', 'companyname': '', 'phone': '5620477', 'email': 'jangulo01@comcast.net'}
# {'firstname': 'Summer', 'lastname': 'Anson', 'companyname': '', 'phone': '4212642', 'email': 'fsu_summer@yahoo.com'}
# {'firstname': 'Robert', 'lastname': 'Apgar', 'companyname': '', 'phone': '5440131', 'email': 'rbrtapgar@gmail.com'}
# {'firstname': 'Doug', 'lastname': 'Apple', 'companyname': '', 'phone': '7667655', 'email': 'dougapple@gmail.com'}
# {'firstname': 'George', 'lastname': 'Apthorp', 'companyname': '', 'phone': '9265045', 'email': 'sandy32327@gmail.com'}
# {'firstname': 'George', 'lastname': 'Arcos', 'companyname': '', 'phone': '4457221', 'email': 'pinf@comcast.net'}
# {'firstname': 'Mary', 'lastname': 'Ardis', 'companyname': '', 'phone': '9422773', 'email': 'his7finisher@gmail.com'}
# {'firstname': 'Bill', 'lastname': 'Armstrong', 'companyname': 'Armstrong Tree Service', 'phone': '8933318', 'email': 'phoumere@hotmail.com'}
# {'firstname': 'Eva', 'lastname': 'Armstrong', 'companyname': '', 'phone': '5919501', 'email': 'evabarmstrong@comcast.net'}
# {'firstname': 'Eva', 'lastname': 'Armstrong', 'companyname': '', 'phone': '5919501', 'email': 'evabarmstrong@comcast.net'}
# {'firstname': 'John', 'lastname': 'Armstrong', 'companyname': '', 'phone': '3090800', 'email': 'adaughtry@americashomeplace.com'}
# {'firstname': 'Anna', 'lastname': 'Arrington', 'companyname': '', 'phone': '2246275', 'email': 'aarrington@benchmarkres.com'}
# {'firstname': 'John', 'lastname': 'Arthur', 'companyname': '', 'phone': '4438055', 'email': 'jarthur45@comcast.net'}
# {'firstname': 'David/Gerilyn', 'lastname': 'Ashburn', 'companyname': '', 'phone': '4258550', 'email': 'dgashburn@comcast.net'}
# {'firstname': 'Hibeh and Mohammed', 'lastname': 'Askar', 'companyname': '', 'phone': '3394020', 'email': 'hibehaskar@outlook.com'}
# {'firstname': 'Hibeh', 'lastname': 'Askar', 'companyname': '', 'phone': '3394020', 'email': 'hibehaskar@outlook.com'}
# {'firstname': 'Mike', 'lastname': 'Askari', 'companyname': '', 'phone': '5566666', 'email': 'mikeaskari@yahoo.com'}
# {'firstname': 'Mike', 'lastname': 'Askari', 'companyname': '', 'phone': '5566666', 'email': 'mikeaskari@yahoo.com'}
# {'firstname': 'Arman', 'lastname': 'Atayants', 'companyname': 'A-1 Services, LLC', 'phone': '5913693', 'email': 'aatayants@gmail.com'}
# {'firstname': 'Armen', 'lastname': 'Atayants', 'companyname': 'Skyline Building & Investments, Inc.', 'phone': '5913693', 'email': 'skylinetally@gmail.com'}
# {'firstname': 'Vaghan', 'lastname': 'Atayants', 'companyname': 'A & W Construction', 'phone': '4083008', 'email': 'aandwconstruction@yahoo.com'}
# {'firstname': 'Vaghan', 'lastname': 'Atayants', 'companyname': 'A & W Construction', 'phone': '4083008', 'email': 'aandwconstruction@yahoo.com'}
# {'firstname': 'Eric', 'lastname': 'Athnos', 'companyname': '', 'phone': '5976764', 'email': 'erik.athnos@gmail.com'}
# {'firstname': 'Everette', 'lastname': 'Atkinson', 'companyname': '', 'phone': '6883094', 'email': 'eatkinson@ejward.com'}
# {'firstname': 'Michael', 'lastname': 'Atkinson', 'companyname': '', 'phone': '2512694', 'email': 'nexnbax1@comcast.net'}
# {'firstname': 'Jennifer', 'lastname': 'Atwell', 'companyname': '', 'phone': '9338872', 'email': 'jenniferatwellrealtor@gmail.com'}
# {'firstname': 'Ed', 'lastname': 'Augustyniak', 'companyname': '', 'phone': '3397323', 'email': 'raugustyniak@admin.fsu.edu'}
# {'firstname': 'Carol', 'lastname': 'Austin', 'companyname': '', 'phone': '8942810', 'email': 'wwlambert@hotmail.com'}
# {'firstname': 'Dale', 'lastname': 'Austin', 'companyname': '', 'phone': '6682471', 'email': 'laustin7@comcast.net'}
# {'firstname': 'John', 'lastname': 'Austin', 'companyname': '', 'phone': '5287566', 'email': 'jaka@embarqmail.com'}
# {'firstname': 'Ken', 'lastname': 'Autry', 'companyname': '', 'phone': '4911270', 'email': 'ken.autry@gmail.com'}
# {'firstname': 'Angie', 'lastname': 'Avery', 'companyname': 'Keller Williams Realty', 'phone': '2944874', 'email': 'angieavery@kw.com'}
# {'firstname': 'Jeff', 'lastname': 'Babcock', 'companyname': '', 'phone': '3919360', 'email': 'jeffrbabcock@yahoo.com'}
# {'firstname': 'Tom and Kacie', 'lastname': 'Bacot', 'companyname': '', 'phone': '2948876', 'email': 'tbacot@gmail.com'}
# {'firstname': 'Matt', 'lastname': 'Baer', 'companyname': '', 'phone': '2125125', 'email': 'kbaer@comcast.net'}
# {'firstname': 'Jeff', 'lastname': 'Baggett', 'companyname': 'Keller Williams Realty', 'phone': '5242778', 'email': 'jefftbaggett@gmail.com'}
# {'firstname': 'John', 'lastname': 'Baggett', 'companyname': '', 'phone': '4452907', 'email': 'bloodwoe@yahoo.com'}
# {'firstname': 'Mary', 'lastname': 'Baggett', 'companyname': '', 'phone': '5242777', 'email': 'mary@realestateintally.com'}
# {'firstname': 'Mary', 'lastname': 'Baggett', 'companyname': '', 'phone': '5242777', 'email': 'mary@realestateintally.com'}
# {'firstname': 'Doug', 'lastname': 'Bailey', 'companyname': '', 'phone': '4454778', 'email': 'dougflyer@yahoo.com'}
# {'firstname': 'Michelle', 'lastname': 'Bailey', 'companyname': '', 'phone': '8410973', 'email': 'mbailey@delmarfinancial.com'}
# {'firstname': 'Michelle', 'lastname': 'Bailey', 'companyname': '', 'phone': '8410973', 'email': 'mbailey@delmarfinancial.com'}
# {'firstname': 'Susan', 'lastname': 'Bailey', 'companyname': '', 'phone': '5918381', 'email': 'sbrb19b56@yahoo.com'}
# {'firstname': 'Melissa and Ben', 'lastname': 'Bakas', 'companyname': '', 'phone': '8327650', 'email': 'msbakas@aol.com'}
# {'firstname': 'Dustin', 'lastname': 'Baker', 'companyname': '', 'phone': '5085872', 'email': 'bakerconstructionllc@ymail.com'}
# {'firstname': 'Jay', 'lastname': 'Baker', 'companyname': '', 'phone': '6681045', 'email': 'hazgroup@comcast.net'}
# {'firstname': 'Joe', 'lastname': 'Baker', 'companyname': '', 'phone': '9337628', 'email': 'banda9801@me.com'}
# {'firstname': 'Shannon', 'lastname': 'Baker', 'companyname': '', 'phone': '2513801', 'email': 'shannon.baker83@comcast.net'}
# {'firstname': 'Tiffany', 'lastname': 'Baker', 'companyname': '', 'phone': '4439336', 'email': 'bakertlaw@gmail.com'}
# {'firstname': 'Keith', 'lastname': 'Balon', 'companyname': '', 'phone': '8934983', 'email': 'keithbalon@embarqmail.com'}
# {'firstname': 'Fariba', 'lastname': 'Baniahmad', 'companyname': '', 'phone': '5094007', 'email': 'fbani3@yahoo.com'}
# {'firstname': 'Diane', 'lastname': 'Barber', 'companyname': '', 'phone': '4919040', 'email': 'dbarber261@yahoo.com'}
# {'firstname': 'Kathleeen', 'lastname': 'Barber', 'companyname': '', 'phone': '4438289', 'email': 'kathleenbarber@comcast.net'}
# {'firstname': 'Robert', 'lastname': 'Barber', 'companyname': '', 'phone': '5092689', 'email': 'housedoc.rb@gmail.com'}
# {'firstname': 'Adam', 'lastname': 'Bardhi', 'companyname': '', 'phone': '2124364', 'email': 'adambardhi@hotmail.com'}
# {'firstname': 'Redjije', 'lastname': 'Bardi', 'companyname': '', 'phone': '2124364', 'email': 'adambardhi@hotmail.com'}
# {'firstname': 'Grady', 'lastname': 'Barnes', 'companyname': '', 'phone': '5442240', 'email': 'tallahasseetaffy@yahoo.com'}
# {'firstname': 'Pamela', 'lastname': 'Barnes', 'companyname': '', 'phone': '5137391', 'email': 'paaabarnes@aol.com'}
# {'firstname': 'Robert', 'lastname': 'Barnette', 'companyname': '', 'phone': '3221325', 'email': 'robert.barnette@hancockbank.com'}
# {'firstname': 'Gary', 'lastname': 'Bartlett', 'companyname': '', 'phone': '4435887', 'email': 'gary@garybartlettrealestate.com'}
# {'firstname': 'Karl', 'lastname': 'Barton', 'companyname': '', 'phone': '2945234', 'email': 'kbartonfl@gmail.com'}
# {'firstname': 'Elvin', 'lastname': 'Bashor', 'companyname': '', 'phone': '4450799', 'email': 'ebashor@flvc.org'}
# {'firstname': 'Eddie', 'lastname': 'Bass', 'companyname': '', 'phone': '5446771', 'email': 'ebass@moorebass.com'}
# {'firstname': 'Eddie', 'lastname': 'Bass', 'companyname': '', 'phone': '5446771', 'email': 'ebass@moorebass.com'}
# {'firstname': 'Eddie', 'lastname': 'Bass', 'companyname': '', 'phone': '5446771', 'email': 'ebass@moorebass.com'}
# {'firstname': 'Noah', 'lastname': 'Bassett', 'companyname': '', 'phone': '5242163', 'email': 'noahbassett1995@gmail.com'}
# {'firstname': 'Susan', 'lastname': 'Bassett', 'companyname': '', 'phone': '3230092', 'email': 'sbassett@stgeorgewired.com'}
# {'firstname': 'Susan', 'lastname': 'Bassett', 'companyname': '', 'phone': '3230092', 'email': 'sbassett@stgeorgewired.com'}
# {'firstname': 'Paul', 'lastname': 'Bass', 'companyname': '', 'phone': '2708450', 'email': 'pbassfamily@gmail.com'}
# {'firstname': 'Anthony', 'lastname': 'Bastian', 'companyname': '', 'phone': '2518299', 'email': 'bastianag@gmail.com'}
# {'firstname': 'Jacqueline', 'lastname': 'Batchelor', 'companyname': '', 'phone': '5673979', 'email': 'jacquebatch@me.com'}
# {'firstname': 'Bruce and Rosemary', 'lastname': 'Bates', 'companyname': '', 'phone': '4591539', 'email': 'brucekevinbates@hotmail.com'}
# {'firstname': 'Carol Ann', 'lastname': 'Bates', 'companyname': '', 'phone': '9426077', 'email': 'carolannbates@live.com'}
# {'firstname': 'Lantz', 'lastname': 'Baum', 'companyname': '', 'phone': '2413507', 'email': 'lantzbaum@gmail.com'}
# {'firstname': 'Bryan', 'lastname': 'Baxley', 'companyname': '', 'phone': '4915404', 'email': 'bryanbaxley@bellsouth.net'}
# {'firstname': 'Debi', 'lastname': 'Baxley', 'companyname': '', 'phone': '2964085', 'email': 'debi.seminole@gmail.com'}
# {'firstname': 'Troy', 'lastname': 'Baxter', 'companyname': 'TLB Properties', 'phone': '4083264', 'email': 'tbaxdeveloper@gmail.com'}
# {'firstname': 'Jason', 'lastname': 'Beam', 'companyname': '', 'phone': '5662544', 'email': 'jwbeam@att.net'}
# {'firstname': 'Virginia', 'lastname': 'Beard', 'companyname': '', 'phone': '7661149', 'email': 'mamadoxie@hotmail.com'}
# {'firstname': 'Mike', 'lastname': 'Beasley', 'companyname': '', 'phone': '5560263', 'email': 'info@southernball.com'}
# {'firstname': 'Jenna', 'lastname': 'Beceriklier', 'companyname': '', 'phone': '5280948', 'email': 'cvfd865@gmail.com'}
# {'firstname': 'Lynn', 'lastname': 'Becker', 'companyname': '', 'phone': '2479202', 'email': 'lynnbecker1217@gmail.com'}
# {'firstname': 'Lynn', 'lastname': 'Becker', 'companyname': '', 'phone': '2479202', 'email': 'lynnbecker1217@gmail.com'}
# {'firstname': 'John', 'lastname': 'Beck', 'companyname': '', 'phone': '2739100', 'email': 'jeb4001@aol.com'}
# {'firstname': 'Steve', 'lastname': 'Bedosky', 'companyname': '', 'phone': '5085313', 'email': 'steve.bedosky@outlook.com'}
# {'firstname': 'Lindsey', 'lastname': 'Begue', 'companyname': '', 'phone': '5976112', 'email': 'closings@manausa.com'}
# {'firstname': 'John', 'lastname': 'Beilder', 'companyname': '', 'phone': '4599879', 'email': 'john.beidler@gmail.com'}
# {'firstname': 'Benton', 'lastname': 'Belcher', 'companyname': '', 'phone': '5705195', 'email': 'benton@easyterritory.com'}
# {'firstname': 'Jamie', 'lastname': 'Bellamy', 'companyname': 'Roberts & Co. Real Estate Svcs', 'phone': '3213276', 'email': 'jamie@robertscorealestate.com'}
# {'firstname': 'Bill', 'lastname': 'Bell', 'companyname': '', 'phone': '5090734', 'email': 'mormonincamo@gmail.com'}
# {'firstname': 'John', 'lastname': 'Bell', 'companyname': '', 'phone': '6278380', 'email': 'johnbell@tds.net'}
# {'firstname': 'Broderick', 'lastname': 'Below', 'companyname': '', 'phone': '4914862', 'email': 'bellowb@embarqmail.com'}
# {'firstname': 'Brianne', 'lastname': 'Beltz', 'companyname': '', 'phone': '2246275', 'email': 'bpm.bbeltz@comcast.net'}
# {'firstname': 'Brianne', 'lastname': 'Beltz', 'companyname': 'Benchmark Property Management', 'phone': '2246275', 'email': 'tmlg.brianne@gmail.com'}
# {'firstname': 'Brianne', 'lastname': 'Beltz', 'companyname': 'Benchmark Property Management', 'phone': '2246275', 'email': 'sfossen@bpmreservices.com'}
# {'firstname': 'Brianne', 'lastname': 'Beltz', 'companyname': 'Benchmark Property Management', 'phone': '2246275', 'email': 'bpm.bbeltz@comcast.net'}
# {'firstname': 'Brianne', 'lastname': 'Beltz', 'companyname': 'Benchmark Property Management', 'phone': '2246275', 'email': 'abarr@benchmarkres.com'}
# {'firstname': 'Sharon', 'lastname': 'Benedict', 'companyname': '', 'phone': '5087075', 'email': 'sharonbenedict2@gmail.com'}
# {'firstname': 'Richard', 'lastname': 'Benham', 'companyname': '', 'phone': '3219612', 'email': 'rbenham@aol.com'}
# {'firstname': 'Brian', 'lastname': 'Bennett', 'companyname': '', 'phone': '4081537', 'email': 'bbennett229@gmail.com'}
# {'firstname': 'Johnny', 'lastname': 'Bennett', 'companyname': '', 'phone': '6947047', 'email': 'johnnyinfp@gmail.com'}
# {'firstname': 'Larry & Stephanie', 'lastname': 'Bennett', 'companyname': '', 'phone': '5283459', 'email': 'star@embarqmail.com'}
# {'firstname': 'Matt', 'lastname': 'Bennett', 'companyname': 'Bennett Better Built Homes', 'phone': '5287102', 'email': 'matt@bennettbetterbuilthomes.com'}
# {'firstname': 'Matt', 'lastname': 'Bennett', 'companyname': 'Bennett Better Built Homes', 'phone': '5287102', 'email': 'matt@bennettbetterbuilthomes.com'}
# {'firstname': 'Ashley', 'lastname': 'Bentley', 'companyname': '', 'phone': '8791090', 'email': 'woodham.ashley@gmail.com'}
# {'firstname': 'Scott', 'lastname': 'Bentz', 'companyname': 'Bentz Construction', 'phone': '5094693', 'email': 'bentzcontractor@centurylink.net'}
# {'firstname': 'Scott', 'lastname': 'Bentz', 'companyname': 'Bentz Construction', 'phone': '5094693', 'email': 'bentzcontractor@centurylink.net'}
# {'firstname': 'Robert', 'lastname': 'Beregowitz', 'companyname': '', 'phone': '2287250', 'email': 'beregowr@gmail.com'}
# {'firstname': 'Angela', 'lastname': 'Berg', 'companyname': '', 'phone': '5907962', 'email': 'alb10j@my.fsu.edu'}
# {'firstname': 'Kathy', 'lastname': 'Berger', 'companyname': '', 'phone': '4454821', 'email': 'kberger62@gmail.com'}
# {'firstname': 'Lee', 'lastname': 'Berger', 'companyname': '', 'phone': '2519322', 'email': 'leebergtally@comcast.net'}
# {'firstname': 'Tom', 'lastname': 'Berger', 'companyname': '', 'phone': '6688160', 'email': 'tombergertb@gmail.com'}
# {'firstname': 'Stephanie', 'lastname': 'Bergozza', 'companyname': '', 'phone': '5452906', 'email': 'stephanie.bergozza@gmail.com'}
# {'firstname': 'Richard', 'lastname': 'Bergstrom', 'companyname': '', 'phone': '2649047', 'email': 'fsuberk11@yahoo.com'}
# {'firstname': 'Mark', 'lastname': 'Berntsen', 'companyname': '', 'phone': '7661228', 'email': 'mbernten@gmail.com'}
# {'firstname': 'Keith', 'lastname': 'Berry', 'companyname': '', 'phone': '4454492', 'email': 'keith.berry2@gmail.com'}
# {'firstname': 'Jason', 'lastname': 'Bertoch', 'companyname': '', 'phone': '8790682', 'email': 'bertoch@gmail.com'}
# {'firstname': 'Charles', 'lastname': 'Bertram', 'companyname': '', 'phone': '5910986', 'email': 'cmbertram@yahoo.com'}
# {'firstname': 'Charles', 'lastname': 'Bertran', 'companyname': '', 'phone': '5910986', 'email': 'cmbertram@yahoo.com'}
# {'firstname': 'David', 'lastname': 'Best', 'companyname': '', 'phone': '5673865', 'email': 'dbest67@gmail.com'}
# {'firstname': 'Nick', 'lastname': 'Bhatty', 'companyname': '', 'phone': '5671627', 'email': 'mtnestllc@gmail.com'}
# {'firstname': 'Tony', 'lastname': 'Bianco', 'companyname': '', 'phone': '2120419', 'email': 'tonymgm@me.com'}
# {'firstname': 'Tony', 'lastname': 'Bianco', 'companyname': '', 'phone': '2120419', 'email': 'tonymgm@me.com'}
# {'firstname': 'Carolee', 'lastname': 'Biddy', 'companyname': '', 'phone': '5360928', 'email': 'cjb777@embarqmail.com'}
# {'firstname': 'Lo', 'lastname': 'Bielby', 'companyname': '', 'phone': '2105513', 'email': 'bielbyl@gtlaw.com'}
# {'firstname': 'Charles & Patty', 'lastname': 'Billings', 'companyname': '', 'phone': '4435056', 'email': 'crbdvm@aol.com'}
# {'firstname': 'Jean', 'lastname': 'Billingsley', 'companyname': '', 'phone': '5564659', 'email': 'jean27111@embarqmail.com'}
# {'firstname': 'Tim', 'lastname': 'Bivens', 'companyname': '', 'phone': '5287782', 'email': 'tim.bivens@comcast.net'}
# {'firstname': 'Heath', 'lastname': 'Blackburn', 'companyname': '', 'phone': '7283381', 'email': 'paolaarbulu@gmail.com'}
# {'firstname': 'Stephen', 'lastname': 'Black', 'companyname': '', 'phone': '3223161', 'email': 'sblackfl@yahoo.com'}
# {'firstname': 'Greg', 'lastname': 'Blair', 'companyname': '', 'phone': '5089645', 'email': 'grskrl@mchsi.com'}
# {'firstname': 'Linda', 'lastname': 'Blake', 'companyname': '', 'phone': '6923868', 'email': 'blake7563@comcast.net'}
# {'firstname': 'Daniel', 'lastname': 'Bland', 'companyname': '', 'phone': '4642595', 'email': 'daned1984@me.com'}
# {'firstname': 'Marshall Reid', 'lastname': 'Blanton', 'companyname': '', 'phone': '5569653', 'email': 'blant157@gmail.com'}
# {'firstname': 'Leonard', 'lastname': 'Blaszczyk', 'companyname': '', 'phone': '8935672', 'email': 'penlental@comcast.net'}
# {'firstname': 'Jeanine', 'lastname': 'Blomberg', 'companyname': '', 'phone': '3215016', 'email': 'jeanine.blomberg@comcast.net'}
# {'firstname': 'Jeanine', 'lastname': 'Blomberg', 'companyname': '', 'phone': '3215016', 'email': 'tgblomberg@aol.com'}
# {'firstname': 'James', 'lastname': 'Blount', 'companyname': '', 'phone': '8784582', 'email': 'masc221@gmail.com'}
# {'firstname': 'James', 'lastname': 'Blount', 'companyname': '', 'phone': '8784582', 'email': 'masc221@gmail.com'}
# {'firstname': 'Lorezo', 'lastname': 'Blue', 'companyname': '', 'phone': '3090800', 'email': 'mparsons@americashomeplace.com'}
# {'firstname': 'Robin', 'lastname': 'Bobin', 'companyname': '', 'phone': '4432254', 'email': 'deltaqueen1@comcast.net'}
# {'firstname': 'Jim', 'lastname': 'Bobrycki', 'companyname': '', 'phone': '5664568', 'email': 'jbobrycki@comcast.net'}
# {'firstname': 'Irwin', 'lastname': 'Bodo', 'companyname': '', 'phone': '4220174', 'email': 'epbodo@comcast.net'}
# {'firstname': 'Glen', 'lastname': 'Boggs', 'companyname': '', 'phone': '5660623', 'email': 'jcorsberg@hotmail.com'}
# {'firstname': 'Carrie', 'lastname': 'Bohanan', 'companyname': '', 'phone': '4597365', 'email': 'punkbug96@aol.com'}
# {'firstname': 'Steve', 'lastname': 'Bohanan', 'companyname': '', 'phone': '5103849', 'email': 'bohanan90@gmail.com'}
# {'firstname': 'Steve', 'lastname': 'Bohl', 'companyname': '', 'phone': '6562056', 'email': 'bohly@comcast.net'}
# {'firstname': 'Steve', 'lastname': 'Bolton', 'companyname': 'Leon Propane', 'phone': '4081334', 'email': 'sbolton@gasinc.net'}
# {'firstname': 'Judy', 'lastname': 'Bone', 'companyname': '', 'phone': '2123429', 'email': 'terrybone@embarqmail.com'}
# {'firstname': 'Doris', 'lastname': 'Bonga', 'companyname': '', 'phone': '5661595', 'email': 'bongad@embarqmail.com'}
# {'firstname': 'Greg', 'lastname': 'Bontz', 'companyname': '', 'phone': '6884022', 'email': 'greg.bontz@homevestors.com'}
# {'firstname': 'Angie', 'lastname': 'Booth', 'companyname': '', 'phone': '5703237', 'email': 'bluedawg630@yahoo.com'}
# {'firstname': 'Brady', 'lastname': 'Bosarge', 'companyname': '', 'phone': '3394335', 'email': 'bradybosarge@yahoo.com'}
# {'firstname': 'Greg', 'lastname': 'Bostwick', 'companyname': '', 'phone': '2510036', 'email': 'greg@espositogardencenter.com'}
# {'firstname': 'Dave', 'lastname': 'Bosworth', 'companyname': '', 'phone': '8090872', 'email': 'dave.bosworth@hendrickauto.com'}
# {'firstname': 'Christina', 'lastname': 'Boulos', 'companyname': '', 'phone': '2288444', 'email': 'cb2676@gmail.com'}
# {'firstname': 'John', 'lastname': 'Bowden', 'companyname': '', 'phone': '5082558', 'email': 'jbmasonry2140@yahoo.com'}
# {'firstname': 'John', 'lastname': 'Bowden', 'companyname': '', 'phone': '5082558', 'email': 'jbmasonry2140@yahoo.com'}
# {'firstname': 'Cecil', 'lastname': 'Bowen', 'companyname': '', 'phone': '2511871', 'email': 'bowen.billy@gc.sysco.com'}
# {'firstname': 'Jack', 'lastname': 'Bower', 'companyname': '', 'phone': '2944531', 'email': 'jbower40@gmail.com'}
# {'firstname': 'Alan', 'lastname': 'Bowers', 'companyname': '', 'phone': '5248681', 'email': 'alanbowersnyc@mac.com'}
# {'firstname': 'Richard', 'lastname': 'Boyd', 'companyname': '', 'phone': '3587373', 'email': 'rboyd@epiphanystar.org'}
# {'firstname': 'Chad', 'lastname': 'Boykin', 'companyname': '', 'phone': '5442629', 'email': 'chad@boykinhomes.com'}
# {'firstname': 'Chad', 'lastname': 'Boykin', 'companyname': '', 'phone': '5442629', 'email': 'chad@boykinhomes.com'}
# {'firstname': 'Chad', 'lastname': 'Boykin', 'companyname': '', 'phone': '5442629', 'email': 'chad@boykinhomes.com'}
# {'firstname': 'Chad', 'lastname': 'Boykin', 'companyname': '', 'phone': '5442629', 'email': 'chad@boykinhomes.com'}
# {'firstname': 'Hugh', 'lastname': 'Boyter', 'companyname': '', 'phone': '3224872', 'email': 'boyterh@comcast.net'}
# {'firstname': 'Russ', 'lastname': 'Brabec', 'companyname': '', 'phone': '3211372', 'email': 'russ@designandmore.com'}
# {'firstname': 'Glenn', 'lastname': 'Bradford', 'companyname': '', 'phone': '9335037', 'email': 'bradford6@rocketmail.com'}
# {'firstname': 'Dustin', 'lastname': 'Bradley', 'companyname': '', 'phone': '5440729', 'email': 'dstn.bradley@gmail.com'}
# {'firstname': 'Bryan and Melinda', 'lastname': 'Bradner', 'companyname': '', 'phone': '2649080', 'email': 'mpbrander@yahoo.com'}
# {'firstname': 'Vanessa', 'lastname': 'Bradshaw', 'companyname': '', 'phone': '5190846', 'email': 'vsbradshaw@aol.com'}
# {'firstname': 'Louis', 'lastname': 'Bramblett', 'companyname': '', 'phone': '9334490', 'email': 'louis_bramblett@yahoo.com'}
# {'firstname': 'Terry', 'lastname': 'Branch', 'companyname': '', 'phone': '5703727', 'email': 'terryabranch@yahoo.com'}
# {'firstname': 'Danielle', 'lastname': 'Branciforte', 'companyname': '', 'phone': '6712556', 'email': 'dtmiot@yahoo.com'}
# {'firstname': 'William', 'lastname': 'Branham', 'companyname': '', 'phone': '3222406', 'email': 'marylinzee@gmail.com'}
# {'firstname': 'Bob', 'lastname': 'Brantly', 'companyname': '', 'phone': '5456001', 'email': 'seafwa@aol.com'}
# {'firstname': 'George', 'lastname': 'Brearley', 'companyname': '', 'phone': '5676797', 'email': 'nsummers2010@gmail.com'}
# {'firstname': 'George', 'lastname': 'Brearley', 'companyname': '', 'phone': '5676797', 'email': 'nsummers2010@gmail.com'}
# {'firstname': 'Jacob', 'lastname': 'Breman', 'companyname': '', 'phone': '6946904', 'email': 'jacob.breman@gmail.com'}
# {'firstname': 'Terri', 'lastname': 'Bremer', 'companyname': '', 'phone': '8690637', 'email': 'terrih623@gmail.com'}
# {'firstname': 'Ken', 'lastname': 'Brewer', 'companyname': 'Leparulo Property Management', 'phone': '2247368', 'email': 'info@leparuloproperties.com'}
# {'firstname': 'Mike', 'lastname': 'Brezin', 'companyname': '', 'phone': '3866767', 'email': 'mbrezin@comcat.net'}
# {'firstname': 'Stuart', 'lastname': 'Briley', 'companyname': '', 'phone': '9079644', 'email': 'bradbri@comcast.net'}
# {'firstname': 'Emma', 'lastname': 'Brinson', 'companyname': '', 'phone': '6172590', 'email': 'emmabrinson@flhsmv.gov'}
# {'firstname': 'Joe', 'lastname': 'Brinson', 'companyname': '', 'phone': '6562360', 'email': 'brinson8247@embarqmail.com'}
# {'firstname': 'Tiffany', 'lastname': 'Brinson', 'companyname': '', 'phone': '5762104', 'email': 'tiffanybrinson77@gmail.com'}
# {'firstname': 'Dustin', 'lastname': 'Brock', 'companyname': '', 'phone': '6948997', 'email': 'dustinbrock73@gmail.com'}
# {'firstname': 'Melissa and Seth', 'lastname': 'Brock', 'companyname': '', 'phone': '2942830', 'email': 'wsethbrock@gmail.com'}
# {'firstname': 'Seth', 'lastname': 'Brock', 'companyname': '', 'phone': '3396983', 'email': 'wsethbrock@gmail.com'}
# {'firstname': 'Seth', 'lastname': 'Brock', 'companyname': '', 'phone': '3396983', 'email': 'wsethbrock@gmail.com'}
# {'firstname': 'Susan', 'lastname': 'Brodbeck', 'companyname': '', 'phone': '5109861', 'email': 'sebbamafl@gmail.com'}
# {'firstname': 'Brandon and Abby', 'lastname': 'Brooks', 'companyname': '', 'phone': '2947252', 'email': 'abbymbrooks@gmail.com'}
# {'firstname': 'George', 'lastname': 'Brophy', 'companyname': '', 'phone': '5592448', 'email': 'gbrophy@kw.com'}
# {'firstname': 'James and Kay', 'lastname': 'Brown', 'companyname': '', 'phone': '6714954', 'email': 'jimmyb8640@gmail.com'}
# {'firstname': 'James', 'lastname': 'Brown', 'companyname': '', 'phone': '8783760', 'email': 'jb591@comcast.net'}
# {'firstname': 'JB', 'lastname': 'Brown', 'companyname': '', 'phone': '2191060', 'email': 'junious.brown@blueprint2000.org'}
# {'firstname': 'Jennifer', 'lastname': 'Brown', 'companyname': '', 'phone': '2849570', 'email': 'jenbrownfl@yahoo.com'}
# {'firstname': 'Martin', 'lastname': 'Brown', 'companyname': '', 'phone': '8936823', 'email': 'martin.brown33@hotmail.com'}
# {'firstname': 'Morris', 'lastname': 'Brown', 'companyname': 'Morris Brown Construction', 'phone': '2100507', 'email': 'morrisb@embarqmail.com'}
# {'firstname': 'Morris', 'lastname': 'Brown', 'companyname': 'Morris Brown Construction', 'phone': '2100507', 'email': 'morrisb@embarqmail.com'}
# {'firstname': 'Katie', 'lastname': 'Brugman', 'companyname': '', 'phone': '3204541', 'email': 'genasgotaggun@gmail.com'}
# {'firstname': 'Louise & Graig', 'lastname': 'Bruner', 'companyname': '', 'phone': '5094430', 'email': 'graigbruner@comcast.com'}
# {'firstname': 'John', 'lastname': 'Bruno', 'companyname': '', 'phone': '3451154', 'email': 'jbruno0802@gmail.com'}
# {'firstname': 'David', 'lastname': 'Bruns', 'companyname': '', 'phone': '7667947', 'email': 'centenarycamp@tds.net'}
# {'firstname': 'Andy', 'lastname': 'Brunson', 'companyname': '', 'phone': '5284290', 'email': 'shanaredinger@gmail.com'}
# {'firstname': 'Hein Allison', 'lastname': 'Bryant', 'companyname': '', 'phone': '3214554', 'email': 'all_is_on2004@yahoo.com'}
# {'firstname': 'Paul', 'lastname': 'Bryant', 'companyname': '', 'phone': '5705500', 'email': 'pgbryant47@gmail.com'}
# {'firstname': 'Marnie', 'lastname': 'Brynes', 'companyname': '', 'phone': '6568607', 'email': 'mbrynes333@yahoo.com'}
# {'firstname': 'Tally', 'lastname': 'Buckles', 'companyname': '', 'phone': '2127375', 'email': 'selkub@hotmail.com'}
# {'firstname': 'Tasha', 'lastname': 'Buford', 'companyname': '', 'phone': '5709641', 'email': 'tashabuford@gmail.com'}
# {'firstname': 'Wayne', 'lastname': 'Bullard', 'companyname': '', 'phone': '3458015', 'email': 'wayne.bullard@comcast.net'}
# {'firstname': 'Daniel', 'lastname': 'Burger', 'companyname': '', 'phone': '5661163', 'email': 'danburger850@gmail.com'}
# {'firstname': 'Don', 'lastname': 'Burger', 'companyname': '', 'phone': '6887083', 'email': 'don.burger@rjyoung.com'}
# {'firstname': 'Karl', 'lastname': 'Burgess', 'companyname': '', 'phone': '4456835', 'email': 'flgator9021@comcast.net'}
# {'firstname': 'Tammy', 'lastname': 'Burgess', 'companyname': '', 'phone': '5709887', 'email': 'tammykburgess@gmail.com'}
# {'firstname': 'Ashley', 'lastname': 'Burk', 'companyname': '', 'phone': '4080175', 'email': 'hay.hbeck@gmail.com'}
# {'firstname': 'Jim', 'lastname': 'Burke', 'companyname': '', 'phone': '8786426', 'email': 'ejburke@embarqmail.com'}
# {'firstname': 'Brad', 'lastname': 'Burleson', 'companyname': '', 'phone': '5452219', 'email': 'brad.burleson@me.com'}
# {'firstname': 'Susan', 'lastname': 'Burnette', 'companyname': '', 'phone': '2648600', 'email': 'svburnette@comcast.net'}
# {'firstname': 'Cassandra', 'lastname': 'Burnham', 'companyname': '', 'phone': '5663643', 'email': 'cburn711@yahoo.com'}
# {'firstname': 'Cassandra', 'lastname': 'Burnham', 'companyname': '', 'phone': '5663643', 'email': 'cburn711@yahoo.com'}
# {'firstname': 'Djenaba', 'lastname': 'Burns', 'companyname': '', 'phone': '3392674', 'email': 'djbakerburns@gmail.com'}
# {'firstname': 'Jeremiah', 'lastname': 'Burns', 'companyname': '', 'phone': '4910256', 'email': 'jeremiahburns08@gmail.com'}
# {'firstname': 'Shannon', 'lastname': 'Burns', 'companyname': '', 'phone': '2121142', 'email': 'jaxhatsandmore@yahoo.com'}
# {'firstname': 'Dale', 'lastname': 'Burris', 'companyname': '', 'phone': '5565553', 'email': 'daleburris2148@comcast.net'}
# {'firstname': 'Blair and Vicky', 'lastname': 'Burton', 'companyname': '', 'phone': '2514722', 'email': 'blair@paulspest.com'}
# {'firstname': 'Susan', 'lastname': 'Burton', 'companyname': '', 'phone': '2513418', 'email': 'newhouse590@gmail.com'}
# {'firstname': 'Kevin', 'lastname': 'Busbee', 'companyname': '', 'phone': '5096625', 'email': 'klbusbee@hotmail.com'}
# {'firstname': 'Allen', 'lastname': 'Busenbark', 'companyname': '', 'phone': '5667378', 'email': 'akjb04@gmail.com'}
# {'firstname': 'Beth', 'lastname': 'Butler', 'companyname': '', 'phone': '8773377', 'email': 'randallvanoss@icloud.com'}
# {'firstname': 'Robert and Heidi', 'lastname': 'Butler', 'companyname': '', 'phone': '8934468', 'email': 'heidiintahiti@hotmail.com'}
# {'firstname': 'Robert', 'lastname': 'Byerts', 'companyname': '', 'phone': '5562395', 'email': 'rbyerts@dealerlawyer.com'}
# {'firstname': 'Jessica', 'lastname': 'Byler', 'companyname': '', 'phone': '5103550', 'email': 'byler764@gmail.com'}
# {'firstname': 'Steven Shon', 'lastname': 'Bynum', 'companyname': '', 'phone': '9338844', 'email': 'ssbynum@gmail.com'}
# {'firstname': 'Jacqueline', 'lastname': 'Byrd', 'companyname': '', 'phone': '7786461', 'email': 'jacquelinebyrd44@yahoo.com'}
# {'firstname': 'Jeanee', 'lastname': 'Byrd', 'companyname': '', 'phone': '4081977', 'email': 'jeanee.e.byrd@gmail.com'}
# {'firstname': 'Roger', 'lastname': 'Cain', 'companyname': '', 'phone': '4918721', 'email': 'roger.cain@yahoo.com'}
# {'firstname': 'Helen', 'lastname': 'Caissie', 'companyname': '', 'phone': '5668998', 'email': 'helencaissie@gmail.com'}
# {'firstname': 'Robin', 'lastname': 'Callahan', 'companyname': '', 'phone': '2515568', 'email': 'robincallahan2010@gmail.com'}
# {'firstname': 'Bob', 'lastname': 'Campbell', 'companyname': '', 'phone': '8932707', 'email': 'bob1402wsl@aol.com'}
# {'firstname': 'Bruce', 'lastname': 'Campbell', 'companyname': '', 'phone': '6569493', 'email': 'subwaysforgod@comcast.net'}
# {'firstname': 'Bruce', 'lastname': 'Campbell', 'companyname': '', 'phone': '3631917', 'email': 'bc5848@msn.com'}
# {'firstname': 'Charlene', 'lastname': 'Campbell', 'companyname': '', 'phone': '3634581', 'email': 'sjamem@gmail.com'}
# {'firstname': 'Dan', 'lastname': 'Campbell', 'companyname': 'Housing for the Glory of God', 'phone': '7662149', 'email': 'ol.danoo@gmail.com'}
# {'firstname': 'Dan', 'lastname': 'Campbell', 'companyname': 'Housing for the Glory of God', 'phone': '7662149', 'email': 'ol.danoo@gmail.com'}
# {'firstname': 'Dan', 'lastname': 'Campbell', 'companyname': 'Housing for the Glory of God', 'phone': '7662149', 'email': 'ol.danoo@gmail.com'}
# {'firstname': 'Dan', 'lastname': 'Campbell', 'companyname': 'Housing for the Glory of God', 'phone': '7662149', 'email': 'ol.danoo@gmail.com'}
# {'firstname': 'Dan', 'lastname': 'Campbell', 'companyname': 'Housing for the Glory of God', 'phone': '7662149', 'email': 'ol.danoo@gmail.com'}
# {'firstname': 'Dan', 'lastname': 'Campbell', 'companyname': 'Housing for the Glory of God', 'phone': '7662149', 'email': 'twriley2012@yahoo.com'}
# {'firstname': 'Leslie', 'lastname': 'Campbell', 'companyname': '', 'phone': '7664626', 'email': 'les.camp@comcast.net'}
# {'firstname': 'Van', 'lastname': 'Campos', 'companyname': '', 'phone': '5622044', 'email': 'vcampos151@yahoo.com'}
# {'firstname': 'Michelle', 'lastname': 'Candies', 'companyname': '', 'phone': '6616032', 'email': 'improveyoursurroundings@hotmail.com'}
# {'firstname': 'Valorie', 'lastname': 'Cannady', 'companyname': '', 'phone': '3631545', 'email': 'haythorn.hillary@ccbg.com'}
# {'firstname': 'Mark', 'lastname': 'Canter', 'companyname': '', 'phone': '5599178', 'email': 'maggie1cnm@gmail.com'}
# {'firstname': 'David', 'lastname': 'Cantrell', 'companyname': '', 'phone': '2162975', 'email': 'david.cantrell@allumni.duke.edu'}
# {'firstname': 'Norine', 'lastname': 'Cardea', 'companyname': '', 'phone': '8770745', 'email': 'ncardea@comcast.net'}
# {'firstname': 'Mirna', 'lastname': 'Cardoza', 'companyname': '', 'phone': '2641257', 'email': 'jessica.helpinghands@gmail.com'}
# {'firstname': 'Lisa', 'lastname': 'Carey', 'companyname': 'Carey & Hart Realtors', 'phone': '2123083', 'email': 'lisa@careyhartrealtors.com'}
# {'firstname': 'Kip', 'lastname': 'Carpenter', 'companyname': "Carpenter's Construction", 'phone': '8780010', 'email': 'kip@kipcarpenter.com'}
# {'firstname': 'Sheri', 'lastname': 'Carpenter', 'companyname': 'Hobbit American Grill', 'phone': '9335533', 'email': 'sheri.carpenter@comcast.net'}
# {'firstname': 'Dennis', 'lastname': 'Carroccio', 'companyname': '', 'phone': '6713768', 'email': 'dfcarro@comcast.net'}
# {'firstname': 'Dwayne', 'lastname': 'Carroll', 'companyname': '', 'phone': '5763763', 'email': 'carrollsboot@aol.com'}
# {'firstname': 'Jewell', 'lastname': 'Carroll', 'companyname': '', 'phone': '3009562', 'email': 'powerspeggy@yahoo.com'}
# {'firstname': 'Nicholas', 'lastname': 'Carroll', 'companyname': '', 'phone': '5083854', 'email': 'carroll.nicholas.a@gmail.com'}
# {'firstname': 'William', 'lastname': 'Carroll', 'companyname': '', 'phone': '2846098', 'email': 'wjc13@embarqmail.com'}
# {'firstname': 'William', 'lastname': 'Carr', 'companyname': '', 'phone': '5399449', 'email': 'junglejimbook@msn.com'}
# {'firstname': 'Sherrie', 'lastname': 'Cartee', 'companyname': '', 'phone': '5456970', 'email': 'cartee11@msn.com'}
# {'firstname': 'Sherrie', 'lastname': 'Cartee', 'companyname': '', 'phone': '5456970', 'email': 'cartee11@msn.com'}
# {'firstname': '', 'lastname': 'Carter', 'companyname': '', 'phone': '3090800', 'email': 'jbodkin@americashomeplace.com'}
# {'firstname': 'Clyde', 'lastname': 'Carter', 'companyname': '', 'phone': '9269991', 'email': 'pennymckinney67@gmail.com'}
# {'firstname': 'Cori and Scott', 'lastname': 'Carter', 'companyname': '', 'phone': '5449557', 'email': 'coricarter.mk@gmail.com'}
# {'firstname': 'RH', 'lastname': 'Carter', 'companyname': 'Carter, R. H.', 'phone': '9263239', 'email': 'wakcosrcit@embarqmail.com'}
# {'firstname': 'RH', 'lastname': 'Carter', 'companyname': '', 'phone': '9263239', 'email': 'wakcosrcit@embarqmail.com'}
# {'firstname': 'RH', 'lastname': 'Carter', 'companyname': '', 'phone': '9263239', 'email': 'wakcosrcit@embarqmail.com'}
# {'firstname': 'Charles & Janet', 'lastname': 'Cascio', 'companyname': '', 'phone': '5456748', 'email': 'geauxcascio@embarqmail.com'}
# {'firstname': 'Mary Catherine', 'lastname': 'Casey', 'companyname': '', 'phone': '5441922', 'email': 'mccasey@fubaworks.com'}
# {'firstname': 'Lisa', 'lastname': 'Cashulette', 'companyname': '', 'phone': '5247064', 'email': 'lcash2005@comcast.net'}
# {'firstname': 'Don', 'lastname': 'Castano', 'companyname': '', 'phone': '9994416', 'email': 'don.castano@comcast.net'}
# {'firstname': 'Dorothy', 'lastname': 'Caswell', 'companyname': '', 'phone': '5534353', 'email': 'kim.gunn@yahoo.com'}
# {'firstname': 'Dee', 'lastname': 'Causseaux', 'companyname': '', 'phone': '3090800', 'email': 'deebbc1993@gmail.com'}
# {'firstname': 'Elizabeth', 'lastname': 'Causseaux', 'companyname': '', 'phone': '4457209', 'email': 'hh910241@gmail.com'}
# {'firstname': 'Adria', 'lastname': 'Cavany', 'companyname': '', 'phone': '5441889', 'email': 'acavany@hotmail.com'}
# {'firstname': 'Daniel', 'lastname': 'Cederholm', 'companyname': '', 'phone': '4591681', 'email': 'dec62@centurylink.net'}
# {'firstname': 'Amy', 'lastname': 'Center', 'companyname': 'Cavallo Farms-Janam Enterprises', 'phone': '5454898', 'email': 'cavallofarms@comcast.net'}
# {'firstname': 'Carly', 'lastname': 'Cermak', 'companyname': '', 'phone': '2286979', 'email': 'carly.cermak@gmail.com'}
# {'firstname': 'Chris', 'lastname': 'Chaback', 'companyname': '', 'phone': '5459317', 'email': 'chris@bsbipartners.com'}
# {'firstname': 'Tom', 'lastname': 'Chambasian', 'companyname': '', 'phone': '6944061', 'email': 'keychambasian@superlube.com'}
# {'firstname': 'Michael', 'lastname': 'Chambers', 'companyname': '', 'phone': '3221567', 'email': 'chambers2267@gmail.com'}
# {'firstname': 'Junita', 'lastname': 'Chamings', 'companyname': '', 'phone': '5391571', 'email': 'peterchamings76@mediacombb.net'}
# {'firstname': 'Pat', 'lastname': 'Chandler', 'companyname': '', 'phone': '2940603', 'email': 'chandler_pat@hotmail.com'}
# {'firstname': 'Andrea', 'lastname': 'Chapman', 'companyname': 'Realtor - Chapman, Andrea', 'phone': '5679181', 'email': 'andreaschapman@gmail.com'}
# {'firstname': 'Thomas', 'lastname': 'Chapman', 'companyname': '', 'phone': '2941648', 'email': 'tjchapman2@gmail.com'}
# {'firstname': 'Carlton', 'lastname': 'Chappell', 'companyname': '', 'phone': '2944999', 'email': 'cclipper75@gmail.com'}
# {'firstname': 'Eleanor', 'lastname': 'Charbneau', 'companyname': '', 'phone': '2965647', 'email': 'latayasullivan@yahoo.com'}
# {'firstname': 'David', 'lastname': 'Charles', 'companyname': '', 'phone': '4879392', 'email': 'david.charles.tallahassee@gmail.com'}
# {'firstname': 'William', 'lastname': 'Chasen', 'companyname': '', 'phone': '5247518', 'email': 'wetumpka@ymail.com'}
# {'firstname': 'Eric', 'lastname': 'Chastain', 'companyname': '', 'phone': '6247766', 'email': 'ericochastain@gmail.com'}
# {'firstname': 'Eric', 'lastname': 'Chastain', 'companyname': '', 'phone': '6247766', 'email': 'ericochastain@gmail.com'}
# {'firstname': 'Heidi', 'lastname': 'Chavers', 'companyname': '', 'phone': '8935565', 'email': 'chaversk@gmail.com'}
# {'firstname': 'Joseph', 'lastname': 'Cheatum', 'companyname': '', 'phone': '6948039', 'email': 'waterwiz4@aol.com'}
# {'firstname': 'Michelle', 'lastname': 'Cherashore', 'companyname': '', 'phone': '9804677', 'email': 'mcherashore@gmail.com'}
# {'firstname': 'Erick', 'lastname': 'Chestnut', 'companyname': '', 'phone': '2512063', 'email': 'chestnuttile@gmail.com'}
# {'firstname': 'Joseph', 'lastname': 'Chiaro', 'companyname': '', 'phone': '5569492', 'email': 'troyanzalone1973@gmail.com'}
# {'firstname': 'Lawton', 'lastname': 'Chiles', 'companyname': '', 'phone': '2518317', 'email': 'budchiles@gmail.com'}
# {'firstname': 'Landon and Angela', 'lastname': 'Chittenden', 'companyname': '', 'phone': '2511903', 'email': 'achittenden@live.com'}
# {'firstname': 'Landon and Angela', 'lastname': 'Chittenden', 'companyname': '', 'phone': '2511903', 'email': 'achittenden@live.com'}
# {'firstname': 'Raleigh', 'lastname': 'Choice', 'companyname': 'Golden Green Builders LLC', 'phone': '5083809', 'email': 'raleighc0708@gmail.com'}
# {'firstname': 'Dane', 'lastname': 'Chrestensen', 'companyname': '', 'phone': '5458340', 'email': 'danechrest@yahoo.com'}
# {'firstname': 'Jamie', 'lastname': 'Christoff', 'companyname': '', 'phone': '5564391', 'email': 'christoff07@gmail.com'}
# {'firstname': 'Chris', 'lastname': 'Church', 'companyname': '', 'phone': '9420179', 'email': 'churchcr@gmail.com'}
# {'firstname': 'Vincent', 'lastname': 'Cicco', 'companyname': '', 'phone': '3639224', 'email': 'vincecicco@hotmail.com'}
# {'firstname': 'Michael', 'lastname': 'Clarey', 'companyname': '', 'phone': '9330664', 'email': 'sycamore5329@yahoo.com'}
# {'firstname': 'Michael', 'lastname': 'Clarey', 'companyname': '', 'phone': '9330664', 'email': 'sycamore5329@yahoo.com'}
# {'firstname': 'Carol', 'lastname': 'Clark', 'companyname': 'Carol Clark Realty Group, LLC', 'phone': '5700581', 'email': 'carol-clark@earthlink.net'}
# {'firstname': 'Ed', 'lastname': 'Clark', 'companyname': 'Construction Support Southeast, Inc', 'phone': '5130300', 'email': 'csselc@aol.com'}
# {'firstname': 'George', 'lastname': 'Clark', 'companyname': '', 'phone': '2109570', 'email': 'dwclark003@gmail.com'}
# {'firstname': 'Michael', 'lastname': 'Clark', 'companyname': '', 'phone': '5451124', 'email': 'clarkmw1@gmail.com'}
# {'firstname': 'Tammy', 'lastname': 'Clark', 'companyname': '', 'phone': '2849448', 'email': 'clarksat35@aol.com'}
# {'firstname': 'Patricia', 'lastname': 'Clements', 'companyname': '', 'phone': '5451484', 'email': 'inthefirstperson@aol.com'}
# {'firstname': 'Patricia', 'lastname': 'Clements', 'companyname': '', 'phone': '5451484', 'email': 'inthefirstperson@aol.com'}
# {'firstname': 'Craig', 'lastname': 'Clemmer', 'companyname': '', 'phone': '2846072', 'email': 'craigclemmer7@gmail.com'}
# {'firstname': 'Heather', 'lastname': 'Clemons', 'companyname': '', 'phone': '2646291', 'email': 'smurf51178@gmail.com'}
# {'firstname': 'Wiley', 'lastname': 'Clifford', 'companyname': '', 'phone': '5105651', 'email': 'wileyclifford@gmail.com'}
# {'firstname': 'Billy', 'lastname': 'Close', 'companyname': '', 'phone': '5453500', 'email': 'closebr@comcast.net'}
# {'firstname': 'Karen', 'lastname': 'Cloud', 'companyname': '', 'phone': '9422441', 'email': 'cadbrae@aol.com'}
# {'firstname': 'Dan', 'lastname': 'Coats', 'companyname': '', 'phone': '5672201', 'email': 'dan.coats@tmh.org'}
# {'firstname': 'Nicholas', 'lastname': 'Cogan', 'companyname': '', 'phone': '5907577', 'email': 'ncogan5@gmail.com'}
# {'firstname': 'Matthew', 'lastname': 'Cohen', 'companyname': '', 'phone': '2945533', 'email': 'lastslade@gmail.com'}
# {'firstname': 'Dustin', 'lastname': 'Cole', 'companyname': '', 'phone': '5097709', 'email': 'scottcallahan@comcast.net'}
# {'firstname': 'Mary', 'lastname': 'Coleman', 'companyname': '', 'phone': '8785883', 'email': 'itashalmt@gmail.com'}
# {'firstname': 'Richard', 'lastname': 'Coleman', 'companyname': '', 'phone': '5455015', 'email': 'nicole_coleman2@yahoo.com'}
# {'firstname': 'Calvin', 'lastname': 'Coley', 'companyname': '', 'phone': '5285899', 'email': 'calvin@dynamicceramic.net'}
# {'firstname': 'Calvin', 'lastname': 'Coley', 'companyname': '', 'phone': '5285899', 'email': 'office.dynamicceramic@gmail.com'}
# {'firstname': 'Elizabeth', 'lastname': 'Collins', 'companyname': '', 'phone': '7281769', 'email': 'edunford66@yahoo.com'}
# {'firstname': 'Fred', 'lastname': 'Collins', 'companyname': '', 'phone': '3214808', 'email': 'kim@collinsaccounting.net'}
# ...
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Board of Commissioners', 'phone': '6061526', 'email': 'heikert@leoncountyfl.gov'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Parks and Recreation', 'phone': '4880221', 'email': 'cozziep@mail.co.leon.fl.us'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Parks and Recreation', 'phone': '4880221', 'email': 'cozziep@mail.co.leon.fl.us'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Parks and Recreation', 'phone': '4880221', 'email': 'cozziep@mail.co.leon.fl.us'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon County Parks and Recreation', 'phone': '4880221', 'email': 'cozziep@mail.co.leon.fl.us'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leon Iron & Metal Inc', 'phone': '5755000', 'email': 'john@leoniron.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leparulo Property Management', 'phone': '2247368', 'email': 'info@leparuloproperties.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Leparulo Property Management', 'phone': '2247368', 'email': 'info@leparuloproperties.com'}
# {'firstname': 'Joann', 'lastname': '', 'companyname': 'Lewis Real Property Managment', 'phone': '5913121', 'email': 'rentals@lewispm.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Lions Gate Church', 'phone': '8791185', 'email': 'postalrebbe@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Lloyd Nursery', 'phone': '5449645', 'email': 'natalie@lloydnursery.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Mad Dog Design & Construction', 'phone': '8788272', 'email': 'curtis@morethanbuildings.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '5661947', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia Properties', 'phone': '2282000', 'email': 'cindy@rentingtallahassee.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Magnolia School', 'phone': '2846892', 'email': 'themagnoliaschool@comcast.net'}
# {'firstname': '', 'lastname': '', 'companyname': 'Mary Ann Chalmers Estate', 'phone': '5089339', 'email': 'natalie5592@hotmail.com'}
# {'firstname': 'Tony', 'lastname': '', 'companyname': 'MasterGranite', 'phone': '2120419', 'email': 'mastergranite@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Metropolitan Cathedral of Truth', 'phone': '7278628', 'email': 'lindastringer47@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Mom & Dads Italian Restaurant', 'phone': '8774518', 'email': 'wcb421@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Mt Zion Baptist Church', 'phone': '5130300', 'email': 'csselc@aol.com'}
# {'firstname': 'Dirk', 'lastname': '', 'companyname': 'Multistone', 'phone': '6100431', 'email': 'dirk@multistoneinc.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Native Nurseries', 'phone': '3868882', 'email': 'mary.m@nativenurseries.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'New South Homes Inc.', 'phone': '2220319', 'email': 'brian@newsouthhomesinc.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'New South Homes Inc.', 'phone': '2220319', 'email': 'brian@newsouthhomesinc.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'North Florida Animal Hospital', 'phone': '3855141', 'email': 'amalone@nva.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Pan Food Store- Apalachee Parkway', 'phone': '6686990', 'email': 'panfoodstores@hotmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Pan Food Store- Mahan Dr', 'phone': '9421007', 'email': 'panfoodstores@hotmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Peavy And Sons Construction Co., Inc', 'phone': '5395019', 'email': 'ensworth@peavyandson.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '5459782', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Quality Construction & Design', 'phone': '8784500', 'email': 'qcdllc@embarqmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Red Rapid Car Wash', 'phone': '6686990', 'email': 'panfoodstores@hotmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Revels Meats', 'phone': '8778808', 'email': 'racecar8832327@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Revels Meats', 'phone': '8778808', 'email': 'racecar8832327@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Rose Speech and Acdemic Cente', 'phone': '5281037', 'email': 'josephstephenrose@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Sam Stevens Construction', 'phone': '5247433', 'email': 'sds2entllc@hotmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Seven Hills Management', 'phone': '6715000', 'email': 'sevenhillsrepairs@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Seven Hills Management', 'phone': '6715000', 'email': 'sevenhillsrepairs@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Shrum, Dena', 'phone': '5106223', 'email': 'dena6223@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Southeast Portable Buildings', 'phone': '5806400', 'email': 'barnsnsheds@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Southeast Portable Buildings', 'phone': '5806400', 'email': 'barnsnsheds@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Sunshine Auto', 'phone': '3912790', 'email': 'sunshineauto@comcast.net'}
# {'firstname': 'Blair', 'lastname': '', 'companyname': 'Superior Realty Group', 'phone': '5705579', 'email': 'blairlapete@yahoo.com'}
# {'firstname': 'Blair', 'lastname': '', 'companyname': 'Superior Realty Group', 'phone': '5705579', 'email': 'blairlapete@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Swain Pool & Spa', 'phone': '5196714', 'email': 'office@swainpools.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Swain Pool & Spa', 'phone': '5196714', 'email': 'office@swainpools.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Tallahassee Mangment', 'phone': '9335009', 'email': 'kdaws850@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Tallahassee Mangment', 'phone': '9335009', 'email': 'kdaws850@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Tallahassee Ranch Club', 'phone': '5442629', 'email': 'chad@boykinhomes.com'}
# {'firstname': 'Ty', 'lastname': '', 'companyname': 'Tallavana Home Owners Associatio', 'phone': '8906509', 'email': 'tylambky.tcon@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Teen Challenge', 'phone': '3858336', 'email': 'kevin.campos@teenchallenge.cc'}
# {'firstname': 'Dennis', 'lastname': '', 'companyname': 'The HoneyBaked Ham Co and Cafe', 'phone': '2051426', 'email': 'dddemshar@yahoo.com'}
# {'firstname': 'Joe', 'lastname': '', 'companyname': 'The Warf', 'phone': '2943705', 'email': 'jfcseafood@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'TOAA LLC', 'phone': '9801680', 'email': 'titusalcorn@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Vintage Homes', 'phone': '7658713', 'email': 'jlinder@vintagehomesfl.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Vintage Homes', 'phone': '7658713', 'email': 'jlinder@vintagehomesfl.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Vintage Homes', 'phone': '7658713', 'email': 'jlinder@vintagehomesfl.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Wayne Frier Homes', 'phone': '5763007', 'email': 'jeffld@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Wayne Frier Homes', 'phone': '5763007', 'email': 'wfhtamela@gmail.com'}
# {'firstname': '', 'lastname': '', 'companyname': "White's Plumbing", 'phone': '5763510', 'email': 'debbie@whitesplumbing.net'}
# {'firstname': '', 'lastname': '', 'companyname': "White's Plumbing", 'phone': '5763510', 'email': 'debbie@whitesplumbing.net'}
# {'firstname': '', 'lastname': '', 'companyname': 'Woodvile IGA', 'phone': '4219132', 'email': 'fsugreg21@aol.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': '', 'lastname': '', 'companyname': 'Word Homes LLC.', 'phone': '2104713', 'email': 'wordhomes@yahoo.com'}
# {'firstname': 'Jason', 'lastname': '', 'companyname': '', 'phone': '3090800', 'email': 'mparsons@americashomeplace.com'}
# {'firstname': 'Edwin', 'lastname': '', 'companyname': '', 'phone': '6178132', 'email': 'valla.ed1@gmail.com'}
# {'firstname': 'Kirk', 'lastname': '', 'companyname': '', 'phone': '3090800', 'email': 'ddahne@americashomeplace.com'}

# %%
from typing import List


t = List[l.Location]
loc = l.Location(locationFieldnames)

# %%
addressPattern = re.compile('(\d*)\s+(.*)')
ret = addressPattern.findall(rows[1]['Street two'])
house, street = ret[0]
print(house)
print(street)

# %%
c0 = C(customerFieldnames)
c0.setCustomer(rows[0])
# custArray: list = [cust]
print(c0)
# print(custArray)

# print(dir(C))

# c0.addLocation(locationFieldnames, rows[0])
# print(c0.locations)

# %%
loc = L.Location(locationFieldnames)
loc.setRow(rows[0])
loc
a = print(loc)
a = f"{a}\n{print(loc)}"


# locations = Locations()
# locations.append(l)
# locations

# it = iter(l for l in locations if l['address1'] if l['state'] == 'FL')
# while True:
#   l = next(it, None)
#   if l:
#     print(l)
#   else:
#     break

# %%
class Phone(str):
  def __init__(self) -> None:
    super().__init__()
  

class Phones(list):
  def __init__(self, phones):
    return super().__init__(str(pn) for pn in phones)
  
  def append(self, phones):
    super().append(str(pn) for pn in phones)


def phoneExists(phoneNumber: str, phones: list):
  if phoneNumber in phones:
    return True
  
  return False
#end checkPhones


def makePhones(row: dict, phones: list):
  # Make an array of non-repeating phone numbers from _row_.
  mp = row['Mobile phone']
  hp = row['Home phone']
  op = row['Office phone']

  if not phoneExists(mp, phones):
    phones.append(mp)
  if not phoneExists(hp, phones):
    phones.append(hp)
  if not phoneExists(op, phones):
    phones.append(op)

  #   if mp:
  #     if not ...:

  #   if hp:
  #     if not mp == hp:
  #       phones.append(hp)
  #       if not mp == op:
  #         phones.append(op)
  #     elif not mp == op:
  #       phones.append(op)
  #     return phones
    
  #   if op:
  #     if not mp == op:
  #       phones.append(op)
    
  #   return phones
  
  # if hp:
  #   phones.append(hp)

  #   if op:
  #     if not hp == op:
  #       phones.append(op)

  #   return phones

  # if op:
  #   phones.append(hp)
  
  return phones
#end makePhones

# %%
p = list()
p.append()

# %%
# with open(csvFile, newline='') as input, open(newCsvFile, 'w', newline='') as output:
#   csvReader = csv.DictReader(input)
#   csvWriter = csv.DictWriter(output)
#   csvWriter.writeheader()

#   for row in csvReader:
#     fn = row['First name']
#     ln = row['Last name']
#     cn = row['Company name']
#     nn = row['Nickname']

#     mp = row['Mobile phone']
#     hp = row['Home phone']
#     op = row['Office phone']

#     s1 = row['Street one']
#     s2 = row['Street two']

#     city = row['City']
#     zip = row['Postal code']

#     email = row['Email']

#     primary = True
#     if row['Primary?'] == "no":
#       primary = False

#     if (len(fn) > 0
#     or len(ln) > 0
#     or len(nn) > 0
#     or len(cn) > 0):

#       if (len(mp) > 0
#       or len(hp) > 0
#       or len(op) > 0):

#         if (len(s1) > 0
#         or len(s2) > 0):

#           if (len(city) > 0
#           or len(zip) > 0):

#             if len(email) > 0:
#               # print(row)
#               csvWriter.writerow(row)




# if re.search(r"^[^\w]*$", row["Last name"]):
#   if re.search(r"^[^\w]*$", row["Company name"]):
#     if len(row["Email"]) > 0:
#       # if not (row["Email"].__contains__("management")
#       # or row["Email"].__contains__("countyfl.gov")
#       # or row["Email"].__contains__("americashomeplace")
#       # or row["Email"].__contains__("snrservices")
#       # or row["Email"].__contains__(".fl.us")
#       # or row["Email"].__contains__("luntconstruction")
#       # or row["Email"].__contains__("nailedit")
#       # or row["Email"].__contains__("jettbuilders")
#       # or row["Email"].__contains__("aatayants")
#       # or row["Email"].__contains__("lzhang22")
#       # or row["Email"].__contains__("armcocabinets")
#       # or row["Email"].__contains__("rbabconstruction")
#       # or row["Email"].__contains__("regentadvisorsllc")
#       # or row["Email"].__contains__("hartsfieldconstruction")
#       # or row["Email"].__contains__("wordhomes")
#       # or row["Email"].__contains__("kentstraussmanagement")
#       # or row['Email'].__contains__('kw')):
#       # print(row["Email"])
#       # count += 1
#       csvWriter.writerow(row)

customers = createCustomerList()

print('Initial customer list')
for c in customerList:
  print(f"Customer {c['firstname']} {c['lastname']}")
  for l in c['locations']:
    print(f"\t{l}")

for row in rows:
  phones = makePhones(row)
  print(phones)
  # locations = makeLocations(row, next(c['locations'] for c in customerList if c['email'] == row['Email']))
  # print(locations)
  # customerList = makeCustomer(row, phones, locations, customerList)

# print('\nFinal customer list')
# for c in customerList:
#   print(f"Customer {c['firstname']} {c['lastname']}")
#   for l in c['locations']:
#     print(f"\t{l}")

# phones = makePhones(row)
# print(phones)
# locations = makeLocations(row, next(c['locations'] for c in customerList if c['email'] == 'joeadamscoast@comcast.net'))
# print(locations)

# l = temp[1]
# l = makeLocation(l['locations'])

# t = next(c for c in temp if c['firstname'] == 'lee')
# print(t['phone'])
# p, index = next(((index, p) for index, p in enumerate(t['phone']) if p['home'] == '902309f2g'), (None, None))
# if not index:
#   print(f"index: {index}")

# d, ii = next((d, ii) for ii, d in enumerate(temp) if d['firstname'] == 'lee')
# print(d)
# print(ii)

# %%
from csv import DictReader


with open(csvFile, newline='') as input, open(jsonFile, 'w', encoding='utf-8') as output:
  csvReader = csv.DictReader(input)
  # jsonWriter = csv.DictWriter(output)

  customers = []
  count = 0

  for row in csvReader:
    email = row['Email']

    # Find if existing customer has same email (assume same customer)
    c, index = next(((c, index) for index, c in enumerate(customers) if c['email'] == email), (None, None))
    if c:
      del customers[index]
      
      # Fill in names, if blank
      if not c['firstname']:
        c['firstname'] = row['First name']
      if not c['lastname']:
        c['lastname'] = row['Last name']
      if not c['companyname']:
        c['companyname'] = row['Company name']
      if not c['nickname']:
        c['nickname'] = row['Nickname']
            
      phones = makePhones(row)
      for p1 in enumerate(row):
        index = next(((index, p) for p in phones if p == p1), None)
        if not index:
          continue
        else:
          del phones[index]


      location = makeLocation(row)
      index, l = next(((index, l) for index, l in enumerate(c['locations']) if l['zipcode'] == location['zipcode']), (None, None))
      if not index:

      if not index == None:
        

          # Search for same location:
          #   Search zip
          #     DNE?: Make location and add
          #   Search address
          #     DNE?: Make location and add

      customers.append(row)

# Need to search in object for matches and inject
    # if row1['Email']:
    #   locationCollection = []
    #   phoneCollection = []

    #   for row2 in csvReader:
    #     if row2['Email'] == row1['Email']:
    #       phoneCollection.append(makePhones(row2))
    #       locationCollection.append(makeLocation(row2))
        
    #     customers.append(makeCustomer(row1, phoneCollection, locationCollection))


    # if (len(fn) > 0
    # or len(ln) > 0
    # or len(nn) > 0
    # or len(cn) > 0):

    #   if (len(mp) > 0
    #   or len(hp) > 0
    #   or len(op) > 0):

    #     if (len(s1) > 0
    #     or len(s2) > 0):

    #       if (len(city) > 0
    #       or len(zip) > 0):

    #         if len(email) > 0:
    #             # print(row)
    #             newRow = {
    #               'firstname': fn,
    #               'lastname': ln,
    #               'companyname': cn,
    #               'nickname': nn,
    #               'phones': {
    #                 'mobile': mp,
    #                 'home': hp,
    #                 'office': op,
    #               },
    #               'locations': {
    #                 'address1': s1,
    #                 'address2': s2,
    #                 'city': city,
    #                 'state': 'FL',
    #                 'zipcode': zip,
    #                 'primary': primary,
    #               },
    #             }
    #             dataDict.append(newRow)
    #             continue

  jsonString = json.dumps(customers, indent=4)
  output.write(jsonString)

  print(count)

# %%
import re

s = 'Lot 10Ck'
# lot10cPattern = re.compile(r'lot[\s]*(?P<lot>\d+)(?P<block>\w{1})', re.IGNORECASE) # Working
lot10cPattern = re.compile(r'lot\s*(\d+)(\w{1})[^\w]*', re.IGNORECASE) # WIP
# lot10BlockCPattern = re.compile(r'lot[\s]*(\d+)\W*block\s*')
m = lot10cPattern.findall(s)
print(m)

# lot10BlockCPattern = re.compile(r'lot[\s]*(\d+)[\W\s]*block(?P<block>\w?)', re.IGNORECASE)
# print(m.group('lot'))
# print(m.group('block'))
# m = re.match(r'lot[\s]*(?P<lot>\d*)(?P<block>\w{1})', s, re.IGNORECASE)
# print(m)
